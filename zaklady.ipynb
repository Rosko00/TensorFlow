# %% [markdown]
# # TensorFlow

# %% [markdown]
# - TensorFlow je open source framework vzvinuty vyskumnikmi Goolge
# - TensorFlow spracovava subory udajov, ktore su usporiadane ako vypoctove uzly vo forme grafu
# - TensorFlow pouzivaju architekturutoku udajov, ktora pracuje so yovseobecnenymi medzivysledkami vypoctov

# %% [markdown]
# ### import TensorFlow

# %%
import tensorflow as tf

# %% [markdown]
# ### Tenzor

# %%
x = tf.constant (([1,2,3],
                 [4,5,6]))

# %%
print (x)
# Out:
# tf.Tensor(
# [[1 2 3]
#  [4 5 6]], shape=(2, 3), dtype=int32)

# %% [markdown]
# ### Shape - informuje o velkosti tenzora po kazdej z jeho osi

# %%
print (x.shape)
# Out:
# (2, 3)

# %% [markdown]
# ### Dtype - informuje o type vsetkych prvkov v tenzore

# %%
print (x.dtype)
# Out:
# <dtype: 'int32'>

# %% [markdown]
# # Matematicke operacie

# %% [markdown]
# ### Scitanie

# %%
(x+x)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[ 2,  4,  6],
#        [ 8, 10, 12]], dtype=int32)>

# %% [markdown]
# ### Nasobenie

# %%
(5*x)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[ 5, 10, 15],
#        [20, 25, 30]], dtype=int32)>

# %% [markdown]
# -
